# %%
import scri
import sxs
import numpy as np
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit



# Download the latest catalog
catalog = sxs.load("catalog",download = False)
# Do some query, this is a pandas dataframe:
ctable = catalog.table
BBHs = ctable[ctable['object_types'] == 'BHBH']
NSBH = ctable[ctable['object_types'] == 'BHNS']
NSNS = ctable[ctable['object_types'] == 'NSNS']

# %% [markdown]
# # Low eccentricity, non- precessing

# %%
BBHs[(BBHs['reference_eccentricity'] < 1.e-4) & (BBHs['reference_chi1_perp'] < 1.e-8) & (BBHs['reference_chi2_perp'] < 1.e-8)]
# Out:
#              object_types  initial_separation  initial_orbital_frequency  \
# SXS:BBH:0012         BHBH           16.000000                   0.014491
# SXS:BBH:0014         BHBH           17.000000                   0.013286
# SXS:BBH:0019         BHBH           16.000000                   0.014447
# SXS:BBH:0031         BHBH           14.000000                   0.017339
# SXS:BBH:0066         BHBH           18.000100                   0.012202
# SXS:BBH:0070         BHBH           18.000000                   0.012202
# SXS:BBH:0180         BHBH           18.000000                   0.012202
# SXS:BBH:0270         BHBH           15.800000                   0.014752
# SXS:BBH:0294         BHBH           15.900000                   0.014559
# SXS:BBH:0295         BHBH           15.100000                   0.015665
# SXS:BBH:2085         BHBH           16.499127                   0.013023
# SXS:BBH:2087         BHBH           16.499673                   0.013294
# SXS:BBH:2088         BHBH           17.998502                   0.012177
# SXS:BBH:2092         BHBH           18.082529                   0.011991
# SXS:BBH:2097         BHBH           16.389386                   0.013915
# SXS:BBH:2099         BHBH           15.583791                   0.014505
# SXS:BBH:2100         BHBH           17.105555                   0.012703
# SXS:BBH:2101         BHBH           16.101124                   0.014127
#
#               initial_adot  initial_ADM_energy  \
# SXS:BBH:0012     -0.000048            0.993695
# SXS:BBH:0014     -0.000038            0.994029
# SXS:BBH:0019     -0.000035            0.993864
# SXS:BBH:0031     -0.000040            0.994433
# SXS:BBH:0066     -0.000025            0.993735
# SXS:BBH:0070     -0.000025            0.993735
# SXS:BBH:0180     -0.000025            0.993735
# SXS:BBH:0270     -0.000046            0.994869
# SXS:BBH:0294     -0.000028            0.995186
# SXS:BBH:0295     -0.000029            0.995674
# SXS:BBH:2085      0.000025            0.993354
# SXS:BBH:2087      0.000016            0.993278
# SXS:BBH:2088     -0.000099            0.993791
# SXS:BBH:2092     -0.000004            0.993742
# SXS:BBH:2097      0.000003            0.993132
# SXS:BBH:2099      0.000212            0.992767
# SXS:BBH:2100     -0.000165            0.993532
# SXS:BBH:2101      0.000064            0.993003
#
#                                    initial_ADM_linear_momentum  \
# SXS:BBH:0012     [-9.7569483e-09, 4.9189483e-09, 5.529549e-10]
# SXS:BBH:0014    [3.1128244e-09, -2.5615531e-09, 5.4325701e-09]
# SXS:BBH:0019   [-2.5215273e-09, -4.072398e-10, 1.64559223e-08]
# SXS:BBH:0031     [3.0246125e-09, -9.827856e-10, 4.6737019e-09]
# SXS:BBH:0066   [-3.1483019e-09, -3.7937639e-09, 1.4360428e-09]
# SXS:BBH:0070    [1.2353239e-09, -4.8770037e-09, 2.5460439e-09]
# SXS:BBH:0180                    [5e-15, 3.539e-13, -3.778e-13]
# SXS:BBH:0270   [-4.7797195e-09, 2.3802125e-09, -2.6947857e-09]
# SXS:BBH:0294  [-7.9303272e-09, -1.7404778e-09, -3.3710274e-09]
# SXS:BBH:0295   [-1.07809299e-08, 5.0369922e-09, 6.8995589e-09]
# SXS:BBH:2085     [-4.7934441e-09, -3.24393471e-08, -2.442e-13]
# SXS:BBH:2087     [1.85597392e-08, 8.28472703e-08, 2.77952e-11]
# SXS:BBH:2088   [-1.93576623e-08, -4.77128435e-08, -1.8282e-12]
# SXS:BBH:2092     [6.47234468e-08, 4.33746965e-08, 3.08974e-11]
# SXS:BBH:2097    [-8.91753503e-08, 4.55234136e-08, 1.29701e-11]
# SXS:BBH:2099          [3.96782359e-08, 3.61874324e-08, -5e-14]
# SXS:BBH:2100        [8.2400014e-09, 3.384941e-10, -3.9669e-12]
# SXS:BBH:2101          [-2.2989e-12, 1.0568988e-09, 1.1685e-12]
#
#               initial_ADM_linear_momentum_mag  \
# SXS:BBH:0012                     1.094074e-08
# SXS:BBH:0014                     6.764913e-09
# SXS:BBH:0019                     1.665297e-08
# SXS:BBH:0031                     5.653109e-09
# SXS:BBH:0066                     5.134848e-09
# SXS:BBH:0070                     5.638575e-09
# SXS:BBH:0180                     5.176901e-13
# SXS:BBH:0270                     5.981053e-09
# SXS:BBH:0294                     8.791085e-09
# SXS:BBH:0295                     1.375513e-08
# SXS:BBH:2085                     3.279159e-08
# SXS:BBH:2087                     8.490074e-08
# SXS:BBH:2088                     5.149014e-08
# SXS:BBH:2092                     7.791335e-08
# SXS:BBH:2097                     1.001230e-07
# SXS:BBH:2099                     5.370189e-08
# SXS:BBH:2100                     8.246952e-09
# SXS:BBH:2101                     1.056902e-09
#
#                                    initial_ADM_angular_momentum  \
# SXS:BBH:0012  [8.006550502e-07, 5.88115691e-08, 0.9205927379...
# SXS:BBH:0014  [1.7107772832e-06, 1.5672810511e-06, 0.9451815...
# SXS:BBH:0019  [1.1286069479e-06, 3.0832898738e-06, 0.9929355...
# SXS:BBH:0031  [6.903254673e-07, 4.31368999e-08, 1.0760479558...
# SXS:BBH:0066  [5.8994449593e-06, -5.254024735e-07, 1.1846240...
# SXS:BBH:0070  [2.4781235396e-06, 5.88698574e-08, 1.184611556...
# SXS:BBH:0180  [-1.5698901172e-06, -3.87578732e-07, 1.1846106...
# SXS:BBH:0270  [1.978549686e-07, -3.349952413e-07, 0.66907004...
# SXS:BBH:0294  [1.705514153e-07, -9.046574864e-07, 0.78179439...
# SXS:BBH:0295  [-8.483646014e-07, 9.995493293e-07, 0.66039989...
# SXS:BBH:2085        [-4.433e-13, 9.097e-13, 1.1440380038179598]
# SXS:BBH:2087     [2.65032e-11, 1.25642e-11, 1.1439582711222933]
# SXS:BBH:2088       [-4.309e-12, 2.4724e-12, 0.9810882799117876]
# SXS:BBH:2092      [-3.256e-13, -1.2692e-12, 1.1851984403418745]
# SXS:BBH:2097    [-3.90708e-11, 1.56172e-11, 1.2098809102526427]
# SXS:BBH:2099     [-4.8059e-12, -5.2188e-12, 1.3948674292199827]
# SXS:BBH:2100     [5.8041e-12, -2.61599e-11, 1.0677604166797625]
# SXS:BBH:2101     [3.67755e-11, 1.93078e-11, 1.2711136694113319]
#
#               initial_ADM_angular_momentum_mag  initial_mass1  ...  \
# SXS:BBH:0012                          0.920593       0.600000  ...
# SXS:BBH:0014                          0.945182       0.600000  ...
# SXS:BBH:0019                          0.992936       0.600000  ...
# SXS:BBH:0031                          1.076048       0.750000  ...
# SXS:BBH:0066                          1.184624       0.500000  ...
# SXS:BBH:0070                          1.184612       0.500000  ...
# SXS:BBH:0180                          1.184611       0.500000  ...
# SXS:BBH:0270                          0.669070       0.750000  ...
# SXS:BBH:0294                          0.781794       0.777778  ...
# SXS:BBH:0295                          0.660400       0.818182  ...
# SXS:BBH:2085                          1.144038       0.500000  ...
# SXS:BBH:2087                          1.143958       0.500000  ...
# SXS:BBH:2088                          0.981088       0.500000  ...
# SXS:BBH:2092                          1.185198       0.500000  ...
# SXS:BBH:2097                          1.209881       0.500000  ...
# SXS:BBH:2099                          1.394867       0.500000  ...
# SXS:BBH:2100                          1.067760       0.500000  ...
# SXS:BBH:2101                          1.271114       0.500000  ...
#
#                                      remnant_dimensionless_spin  \
# SXS:BBH:0012  [3.17933209092e-08, 9.1501306625e-09, 0.540383...
# SXS:BBH:0014  [-1.38022394836e-09, 1.77730015903e-10, 0.5402...
# SXS:BBH:0019  [8.18189877206e-09, 7.36096133903e-08, 0.58675...
# SXS:BBH:0031  [-1.72916805313e-08, -8.27039434208e-09, 0.755...
# SXS:BBH:0066  [-4.94103538319e-10, 1.0269175821e-09, 0.68646...
# SXS:BBH:0070  [-4.2696916721e-10, 1.00184375916e-09, 0.68645...
# SXS:BBH:0180  [-2.14539980535e-13, -8.96386037449e-12, 0.686...
# SXS:BBH:0270  [-1.22561441154e-09, -2.44287387692e-10, 0.396...
# SXS:BBH:0294  [7.86083438542e-10, -8.05221118883e-10, 0.5041...
# SXS:BBH:0295  [-6.68280276097e-10, 4.03846999355e-10, 0.4425...
# SXS:BBH:2085  [5.9417690352e-10, -7.76022731593e-10, 0.68352...
# SXS:BBH:2087  [5.21155603172e-10, -8.82625863928e-10, 0.6841...
# SXS:BBH:2088  [-3.50957221293e-10, 1.02239154787e-09, 0.5477...
# SXS:BBH:2092  [-1.06337103938e-10, -3.68087245961e-10, 0.685...
# SXS:BBH:2097  [1.51558274172e-10, 4.67837048955e-11, 0.73154...
# SXS:BBH:2099  [1.36010809572e-09, -6.2320182754e-10, 0.85739...
# SXS:BBH:2100  [3.72952501551e-09, 1.04976184134e-09, 0.62287...
# SXS:BBH:2101  [-1.1045308083e-09, 9.72443418648e-11, 0.77493...
#
#               remnant_dimensionless_spin_mag  \
# SXS:BBH:0012                        0.540384
# SXS:BBH:0014                        0.540291
# SXS:BBH:0019                        0.586755
# SXS:BBH:0031                        0.755237
# SXS:BBH:0066                        0.686460
# SXS:BBH:0070                        0.686460
# SXS:BBH:0180                        0.686430
# SXS:BBH:0270                        0.396917
# SXS:BBH:0294                        0.504184
# SXS:BBH:0295                        0.442574
# SXS:BBH:2085                        0.683527
# SXS:BBH:2087                        0.684157
# SXS:BBH:2088                        0.547767
# SXS:BBH:2092                        0.685545
# SXS:BBH:2097                        0.731546
# SXS:BBH:2099                        0.857399
# SXS:BBH:2100                        0.622873
# SXS:BBH:2101                        0.774936
#
#                                                remnant_velocity  \
# SXS:BBH:0012  [0.000765516198877, -0.000166763615435, 8.0898...
# SXS:BBH:0014  [-0.000754582623053, -1.04743563801e-06, 2.639...
# SXS:BBH:0019  [-0.000499686481837, 0.000847003894418, 4.9759...
# SXS:BBH:0031  [2.50552081194e-05, -0.000246716341091, -2.683...
# SXS:BBH:0066  [2.25213277561e-09, -5.74740218745e-10, 3.7317...
# SXS:BBH:0070  [1.88811255511e-09, -8.02529007847e-10, 3.6456...
# SXS:BBH:0180  [1.16344449238e-09, -1.34056302822e-09, 1.0618...
# SXS:BBH:0270  [-0.000718994630675, 1.62977508914e-05, 7.1970...
# SXS:BBH:0294  [0.000103772544731, -0.000559649923088, 1.0574...
# SXS:BBH:0295  [-0.000483168242054, -2.62109355106e-05, 5.368...
# SXS:BBH:2085  [0.0005483392925, 0.00126895132991, 2.80072414...
# SXS:BBH:2087  [0.000372432449033, 0.00117309170399, -1.68344...
# SXS:BBH:2088  [-8.67837008302e-05, 0.000298021584503, -1.640...
# SXS:BBH:2092  [6.7504241643e-05, 0.000766729799991, -9.05814...
# SXS:BBH:2097  [-0.000199064426847, 9.04861444561e-05, -1.076...
# SXS:BBH:2099  [-0.000185092645219, 4.09125611123e-05, -2.991...
# SXS:BBH:2100  [-0.000459395309458, 0.00103163755393, 4.93204...
# SXS:BBH:2101  [-0.000382134077595, -0.00012004351296, 2.1638...
#
#               remnant_velocity_mag  eos  initial_data_type disk_mass  \
# SXS:BBH:0012          7.834699e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:0014          7.545834e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:0019          9.834135e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:0031          2.479853e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:0066          4.396426e-09  NaN           BBH_CFMS       NaN
# SXS:BBH:0070          4.183311e-09  NaN           BBH_CFMS       NaN
# SXS:BBH:0180          1.076575e-08  NaN           BBH_CFMS       NaN
# SXS:BBH:0270          7.191793e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:0294          5.691896e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:0295          4.838787e-04  NaN           BBH_CFMS       NaN
# SXS:BBH:2085          1.382358e-03  NaN            BBH_SKS       NaN
# SXS:BBH:2087          1.230792e-03  NaN            BBH_SKS       NaN
# SXS:BBH:2088          3.104002e-04  NaN            BBH_SKS       NaN
# SXS:BBH:2092          7.696957e-04  NaN            BBH_SKS       NaN
# SXS:BBH:2097          2.186650e-04  NaN            BBH_SKS       NaN
# SXS:BBH:2099          1.895603e-04  NaN            BBH_SKS       NaN
# SXS:BBH:2100          1.129301e-03  NaN            BBH_SKS       NaN
# SXS:BBH:2101          4.005458e-04  NaN            BBH_SKS       NaN
#
#              ejecta_mass                                     url  \
# SXS:BBH:0012         NaN  https://doi.org/10.5281/zenodo.1212642
# SXS:BBH:0014         NaN  https://doi.org/10.5281/zenodo.1212652
# SXS:BBH:0019         NaN  https://doi.org/10.5281/zenodo.1212673
# SXS:BBH:0031         NaN  https://doi.org/10.5281/zenodo.1212711
# SXS:BBH:0066         NaN  https://doi.org/10.5281/zenodo.1212944
# SXS:BBH:0070         NaN  https://doi.org/10.5281/zenodo.1213244
# SXS:BBH:0180         NaN  https://doi.org/10.5281/zenodo.1214858
# SXS:BBH:0270         NaN  https://doi.org/10.5281/zenodo.1214614
# SXS:BBH:0294         NaN  https://doi.org/10.5281/zenodo.1215397
# SXS:BBH:0295         NaN  https://doi.org/10.5281/zenodo.1215407
# SXS:BBH:2085         NaN  https://doi.org/10.5281/zenodo.2630961
# SXS:BBH:2087         NaN  https://doi.org/10.5281/zenodo.2630976
# SXS:BBH:2088         NaN  https://doi.org/10.5281/zenodo.2630978
# SXS:BBH:2092         NaN  https://doi.org/10.5281/zenodo.2630988
# SXS:BBH:2097         NaN  https://doi.org/10.5281/zenodo.2631037
# SXS:BBH:2099         NaN  https://doi.org/10.5281/zenodo.2631048
# SXS:BBH:2100         NaN  https://doi.org/10.5281/zenodo.2631056
# SXS:BBH:2101         NaN  https://doi.org/10.5281/zenodo.2631058
#
#                                   metadata_path
# SXS:BBH:0012  SXS:BBH:0012v5/Lev5/metadata.json
# SXS:BBH:0014  SXS:BBH:0014v5/Lev5/metadata.json
# SXS:BBH:0019  SXS:BBH:0019v5/Lev5/metadata.json
# SXS:BBH:0031  SXS:BBH:0031v5/Lev5/metadata.json
# SXS:BBH:0066  SXS:BBH:0066v5/Lev5/metadata.json
# SXS:BBH:0070  SXS:BBH:0070v5/Lev5/metadata.json
# SXS:BBH:0180  SXS:BBH:0180v5/Lev4/metadata.json
# SXS:BBH:0270  SXS:BBH:0270v5/Lev5/metadata.json
# SXS:BBH:0294  SXS:BBH:0294v5/Lev4/metadata.json
# SXS:BBH:0295  SXS:BBH:0295v5/Lev5/metadata.json
# SXS:BBH:2085  SXS:BBH:2085v4/Lev4/metadata.json
# SXS:BBH:2087  SXS:BBH:2087v4/Lev4/metadata.json
# SXS:BBH:2088  SXS:BBH:2088v4/Lev4/metadata.json
# SXS:BBH:2092  SXS:BBH:2092v4/Lev4/metadata.json
# SXS:BBH:2097  SXS:BBH:2097v4/Lev4/metadata.json
# SXS:BBH:2099  SXS:BBH:2099v4/Lev4/metadata.json
# SXS:BBH:2100  SXS:BBH:2100v4/Lev4/metadata.json
# SXS:BBH:2101  SXS:BBH:2101v4/Lev4/metadata.json
#
# [18 rows x 56 columns]

# %%
system='SXS:BBH:2085'

# %%
def MT_to_WM(h_mts, dataType=scri.h):
    h = scri.WaveformModes(t=h_mts.t,\
                           data=np.array(h_mts),\
                           ell_min=h_mts.ell_min,\
                           ell_max=h_mts.ell_max,\
                           frameType=scri.Inertial,\
                           dataType=dataType
                           )
    h.r_is_scaled_out = True
    h.m_is_scaled_out = True
    return h

# %%
md = sxs.load(system + "/Lev/metadata.json")
waveform = sxs.load(system + "/Lev/rhOverM", extrapolation_order=4)

h = MT_to_WM(waveform)
t = h.t

 # slice from relaxation time to peak time
i_relax = np.abs(t-md.relaxation_time).argmin()
i_peak = h.max_norm_index()
cut = slice(i_relax, i_peak)

E = scri.energy_flux(h)[cut]
L = scri.angular_momentum_flux(h)[cut]
ω = scri.angular_velocity(h)[cut]

F = E - np.einsum('ij,ij->i',ω, L)
ω_mod = np.linalg.norm(ω,axis=1)
# Out:
# Found the following files to load from the SXS catalog:
#     SXS:BBH:2085v4/Lev4/metadata.json
# Found the following files to load from the SXS catalog:
#     SXS:BBH:2085v4/Lev4/rhOverM_Asymptotic_GeometricUnits_CoM.h5

# %%
x = t[cut]
y = ω_mod
z = F
plt.plot(x,y)
plt.plot(x,z)

#plt.ylim(-4.3,-4.1)
plt.show()

# %%
x = t[cut]
y = ω_mod
z = F
plt.plot(x,np.log(y))
plt.plot(x,np.log(z))

#plt.ylim(-4.3,-4.1)
plt.show()

# %%
system='SXS:BBH:1533'

# %%
md = sxs.load(system + "/Lev/metadata.json")
waveform = sxs.load(system + "/Lev/rhOverM", extrapolation_order=4)

h = MT_to_WM(waveform)
t = h.t

 # slice from relaxation time to peak time
i_relax = np.abs(t-md.relaxation_time).argmin()
i_peak = h.max_norm_index()
cut = slice(i_relax, i_peak)

E = scri.energy_flux(h)[cut]
L = scri.angular_momentum_flux(h)[cut]
ω = scri.angular_velocity(h)[cut]

F = E - np.einsum('ij,ij->i',ω, L)
ω_mod = np.linalg.norm(ω,axis=1)
# Out:
# Found the following files to load from the SXS catalog:
#     SXS:BBH:1533v4/Lev3/metadata.json
# Found the following files to load from the SXS catalog:
#     SXS:BBH:1533v4/Lev3/rhOverM_Asymptotic_GeometricUnits_CoM.h5

# %%
x = t[cut]
y = ω_mod
z = F
plt.plot(x,y)
plt.plot(x,z)

#plt.ylim(-4.3,-4.1)
plt.show()

# %%
x = t[cut]
y = ω_mod
z = F
plt.plot(x,np.log(y))
plt.plot(x[1000:],np.log(z)[1000:])

#plt.ylim(-4.3,-4.1)
plt.show()

# %%
system='SXS:BBH:1367'

# %%
md = sxs.load(system + "/Lev/metadata.json")
waveform = sxs.load(system + "/Lev/rhOverM", extrapolation_order=4)

h = MT_to_WM(waveform)
t = h.t

 # slice from relaxation time to peak time
i_relax = np.abs(t-md.relaxation_time).argmin()
i_peak = h.max_norm_index()
cut = slice(i_relax, i_peak)

E = scri.energy_flux(h)[cut]
L = scri.angular_momentum_flux(h)[cut]
ω = scri.angular_velocity(h)[cut]

F = E - np.einsum('ij,ij->i',ω, L)
ω_mod = np.linalg.norm(ω,axis=1)
# Out:
# Found the following files to load from the SXS catalog:
#     SXS:BBH:1367v5/Lev5/metadata.json
# Found the following files to load from the SXS catalog:
#     SXS:BBH:1367v5/Lev5/rhOverM_Asymptotic_GeometricUnits_CoM.h5

# %%
x = t[cut]
y = ω_mod
z = F
plt.plot(x,y)
plt.plot(x,z)
#plt.ylim(-0.00021,0.00021)
plt.show()

# %%
x = t[cut]
y = ω_mod
z = F
plt.plot(x,np.log(y),label='log_ω')
plt.plot(x,np.log(z),label='log_F')
plt.ylabel("log ω or log F" )
plt.xlabel("t")
plt.legend()
#plt.ylim(-4.3,-4.1)
plt.show()
